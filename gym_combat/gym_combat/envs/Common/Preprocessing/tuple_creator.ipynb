# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import pandas as pd

# %%
e = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256.txt")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/3643754595.py in <module>
# ----> 1 e = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256.txt")
#
# c:\users\inbalw\pycharmprojects\dll_try\venv\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# c:\users\inbalw\pycharmprojects\dll_try\venv\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# c:\users\inbalw\pycharmprojects\dll_try\venv\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256.txt not found.

# %%
i = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256_inbal.txt")

# %%
plt.imshow(e)
plt.show()

# %%
plt.imshow(i)
plt.show()

# %%
e1 = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256_old.txt")
plt.imshow(e1)
plt.show()

# %%
(e==i).all()

# %%
with open('C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs//Common/Preprocessing/dictionary_position_los_100X100_Berlin_10.pkl', 'rb') as f:
    DICT_POS_LOS = pickle.load(f)

# %%
def list_dict_2_tuple_dict(in_dict):
    out_dict = {}
    for k,v in in_dict.items():
        if v:
            p = np.array(v)
            out_dict[k] = (p[:,0],p[:,1]) 
        else: 
            out_dict[k] = ([],[])
    return out_dict

# %%
path = 'C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs//Common/Preprocessing'

# %%
for filename in os.listdir(path):
    if "position_los" in filename:
        outfile = filename[:-4] + "_tuple.pkl"
        print (outfile)
        with open(os.path.join(path, filename), 'rb') as f:
            in_dict = pickle.load(f)
        out_dict = list_dict_2_tuple_dict(in_dict)
        with open(os.path.join(path, outfile), 'wb') as f_out:
            pickle.dump(out_dict,f_out)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/2428947989.py in <module>
# ----> 1 for filename in os.listdir(path):
#       2     if "position_los" in filename:
#       3         outfile = filename[:-4] + "_tuple.pkl"
#       4         print (outfile)
#       5         with open(os.path.join(path, filename), 'rb') as f:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs//Common/Preprocessing'

# %%
DICT_POS_LOS_AS_TUPLE[(15,15)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/2315155192.py in <module>
# ----> 1 DICT_POS_LOS_AS_TUPLE[(15,15)]
#
# NameError: name 'DICT_POS_LOS_AS_TUPLE' is not defined

# %%
pickle.dump()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/2374814760.py in <module>
# ----> 1 pickle.dump()
#
# TypeError: dump() missing required argument 'obj' (pos 1)

# %%
a[(np.array([]),np.array([]))] = 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/2202406935.py in <module>
# ----> 1 a[(np.array([]),np.array([]))] = 4
#
# NameError: name 'a' is not defined

# %%
np.array([])
# Out:
# array([], dtype=float64)

# %%
a[([2],[2])] = 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/1250979255.py in <module>
# ----> 1 a[([2],[2])] = 4
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/2167009006.py in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
p = []
if p:
    print(1)
else:
    print (2)
# Out:
# 2

# %%
res_path = 'combat_gym/res/'
plt.figure(figsize=(16, 16))
        
for f in os.listdir(res_path):
    csv_file = os.path.join(res_path, f)
    df = pd.read_csv(csv_file, names = ["steps", "success ratio"])
    if "0.99" not in f:
        plt.plot(df["steps"], df["success ratio"], label = f[16:20])
   # df.plot(x = "steps", ylabel =f)
plt.legend(fontsize=14)
plt.xlabel("training steps")
plt.title("checking gamma")
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/77714964.py in <module>
#       2 plt.figure(figsize=(16, 16))
#       3
# ----> 4 for f in os.listdir(res_path):
#       5     csv_file = os.path.join(res_path, f)
#       6     df = pd.read_csv(csv_file, names = ["steps", "success ratio"])
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'combat_gym/res/'

# %%
for filename in os.listdir(path):
    if "position_los" in filename and "Baqa" in filename:
        outfile = filename[:-4] + "_tuple.pkl"
        print (outfile)
        with open(os.path.join(path, filename), 'rb') as f:
            in_dict = pickle.load(f)
        out_dict = list_dict_2_tuple_dict(in_dict)
        with open(os.path.join(path, outfile), 'wb') as f_out:
            pickle.dump(out_dict,f_out)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15184/3141741978.py in <module>
# ----> 1 for filename in os.listdir(path):
#       2     if "position_los" in filename and "Baqa" in filename:
#       3         outfile = filename[:-4] + "_tuple.pkl"
#       4         print (outfile)
#       5         with open(os.path.join(path, filename), 'rb') as f:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs//Common/Preprocessing'
