# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import pandas as pd

# %%
e = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256.txt")

# %%
i = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256_inbal.txt")

# %%
plt.imshow(e)
plt.show()

# %%
plt.imshow(i)
plt.show()

# %%
e1 = np.loadtxt("C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs/Common/maps/Berlin_1_256_old.txt")
plt.imshow(e1)
plt.show()

# %%
(e==i).all()
# Out:
# True

# %%
with open('C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs//Common/Preprocessing/dictionary_position_los_100X100_Berlin_10.pkl', 'rb') as f:
    DICT_POS_LOS = pickle.load(f)

# %%
def list_dict_2_tuple_dict(in_dict):
    out_dict = {}
    for k,v in in_dict.items():
        if v:
            p = np.array(v)
            out_dict[k] = (p[:,0],p[:,1]) 
        else: 
            out_dict[k] = ([],[])
    return out_dict

# %%
path = 'C:/Users/eranice/Documents/FPS_Inbal/combat_gym/gym_combat/gym_combat/envs//Common/Preprocessing'

# %%
for filename in os.listdir(path):
    if "position_los" in filename:
        outfile = filename[:-4] + "_tuple.pkl"
        print (outfile)
        with open(os.path.join(path, filename), 'rb') as f:
            in_dict = pickle.load(f)
        out_dict = list_dict_2_tuple_dict(in_dict)
        with open(os.path.join(path, outfile), 'wb') as f_out:
            pickle.dump(out_dict,f_out)
# Out:
# dictionary_position_los_tuple.pkl
# dictionary_position_los_100X100_Berlin_tuple.pkl
# dictionary_position_los_100X100_Berlin_10_tuple.pkl
# dictionary_position_los_100X100_Berlin_15_tuple.pkl
# dictionary_position_los_100X100_Berlin_20_tuple.pkl
# dictionary_position_los_100X100_Berlin_25_tuple.pkl
# dictionary_position_los_100X100_Berlin_30_tuple.pkl
# dictionary_position_los_100X100_Berlin_7_tuple.pkl
# dictionary_position_los_100X100_Boston_tuple.pkl
# dictionary_position_los_100X100_Boston_10_tuple.pkl
# dictionary_position_los_100X100_Boston_15_tuple.pkl
# dictionary_position_los_100X100_Paris_tuple.pkl
# dictionary_position_los_100X100_Paris_10_tuple.pkl
# dictionary_position_los_100X100_Paris_15_tuple.pkl
# dictionary_position_los_15X15_tuple.pkl
# dictionary_position_los_15X15_14_tuple.pkl
# dictionary_position_los_15X15_7_tuple.pkl
# dictionary_position_los_tuple_tuple.pkl
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-5cdd42c0b94c> in <module>
#       5         with open(os.path.join(path, filename), 'rb') as f:
#       6             in_dict = pickle.load(f)
# ----> 7         out_dict = list_dict_2_tuple_dict(in_dict)
#       8         with open(os.path.join(path, outfile), 'wb') as f_out:
#       9             pickle.dump(out_dict,f_out)
#
# <ipython-input-48-4708bab79077> in list_dict_2_tuple_dict(in_dict)
#       4         if v:
#       5             p = np.array(v)
# ----> 6             out_dict[k] = (p[:,0],p[:,1])
#       7         else:
#       8             out_dict[k] = ([],[])
#
# IndexError: index 0 is out of bounds for axis 1 with size 0

# %%
DICT_POS_LOS_AS_TUPLE[(15,15)]
# Out:
# (array([ 6,  7,  7,  7,  8,  8,  9, 10, 10, 11, 11, 12, 12, 13, 13, 13, 14,
#         14, 14, 15, 15, 15, 16, 16, 16, 17, 17, 17, 18, 18, 18, 19, 19, 19,
#         20, 20, 21, 21, 21, 22, 22, 22, 23, 23, 23, 24, 24, 24, 25]),
#  array([11, 10, 11, 12, 11, 12, 12, 12, 13, 12, 13, 12, 13, 12, 13, 14, 13,
#         14, 15, 13, 14, 15, 13, 14, 15, 13, 14, 15, 13, 14, 15, 13, 14, 15,
#         14, 15, 14, 15, 16, 14, 15, 16, 14, 15, 16, 14, 15, 16, 15]))

# %%
pickle.dump()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-c9ccbb70c7db> in <module>
# ----> 1 p[:,0]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
a[(np.array([]),np.array([]))] = 4
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-0a46396840b9> in <module>
# ----> 1 a[(np.array([]),np.array([]))] = 4
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
np.array([])
# Out:
# array([], dtype=float64)

# %%
a[([2],[2])] = 4

# %%
a
# Out:
# array([[1., 1., 1., 1.],
#        [3., 3., 3., 1.],
#        [1., 1., 4., 1.]])

# %%
p = []
if p:
    print(1)
else:
    print (2)
# Out:
# 2

# %%
res_path = 'combat_gym/res/'
plt.figure(figsize=(16, 16))
        
for f in os.listdir(res_path):
    csv_file = os.path.join(res_path, f)
    df = pd.read_csv(csv_file, names = ["steps", "success ratio"])
    if "0.99" not in f:
        plt.plot(df["steps"], df["success ratio"], label = f[16:20])
   # df.plot(x = "steps", ylabel =f)
plt.legend(fontsize=14)
plt.xlabel("training steps")
plt.title("checking gamma")
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.show()

# %%
for filename in os.listdir(path):
    if "position_los" in filename and "Baqa" in filename:
        outfile = filename[:-4] + "_tuple.pkl"
        print (outfile)
        with open(os.path.join(path, filename), 'rb') as f:
            in_dict = pickle.load(f)
        out_dict = list_dict_2_tuple_dict(in_dict)
        with open(os.path.join(path, outfile), 'wb') as f_out:
            pickle.dump(out_dict,f_out)
# Out:
# dictionary_position_los_Baqa_10_tuple.pkl
# dictionary_position_los_Baqa_30_tuple.pkl
